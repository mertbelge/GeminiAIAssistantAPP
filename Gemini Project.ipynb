# %%
import os
import google.generativeai as genai

api = os.environ["GOOGLE_API_KEY"] = "AIzaSyCN4mz1yTsqHRPLeekunMV6d47Abp82ML4"

genai.configure(api_key=api)

model = genai.GenerativeModel('gemini-1.5-flash')

# %%
#1. Hasta Memnuniyeti Anketi (Kötü Prompt)

chat_session = model.start_chat(
  history = []
)

prompt = "Anket nasıl yapılır?"

response = chat_session.send_message(prompt)

print("Q: " + prompt + "\n\nA: " + response.text)
# Out:
# Q: Anket nasıl yapılır?
#
# A: Anket yapmak, hedef kitlenizden bilgi toplamanın etkili bir yoludur.  Anketin başarısı, planlama, tasarım ve dağıtım aşamalarına bağlıdır. İşte adım adım bir anket nasıl yapılır:
#
# **1. Planlama Aşaması:**
#
# * **Hedefinizi belirleyin:** Anketinizin amacı nedir? Ne öğrenmek istiyorsunuz? Belirli sorularınız mı var yoksa genel bir fikir mi edinmek istiyorsunuz?  (Örneğin: Yeni bir ürün için müşteri memnuniyetini ölçmek, bir hizmeti iyileştirmek için geri bildirim toplamak, pazar araştırması yapmak)
# * **Hedef kitlenizi belirleyin:** Anketinizi kime yönelteceksiniz?  Kimlerden bilgi toplamak istiyorsunuz?  Hedef kitlenizin demografik özellikleri (yaş, cinsiyet, eğitim düzeyi vb.) anket sorularınızı etkileyebilir.
# * **Anket türünü seçin:**
#     * **Açık uçlu sorular:** Katılımcılara özgürce yanıt verme olanağı sağlar (örneğin, "Bu ürün hakkında neler düşünüyorsunuz?").  Analizi daha zor olabilir.
# ...

# %%
#1. Hasta Memnuniyeti Anketi (İyi Prompt)

chat_session = model.start_chat(
  history = []
)

prompt = "Hastane hizmetlerinin kalitesini ölçmek için etkili bir hasta memnuniyeti anketi nasıl hazırlanır?"

response = chat_session.send_message(prompt)

print("Q: " + prompt + "\n\nA: " + response.text)
# Out:
# Q: Hastane hizmetlerinin kalitesini ölçmek için etkili bir hasta memnuniyeti anketi nasıl hazırlanır?
#
# A: Hastane hizmetlerinin kalitesini ölçmek için etkili bir hasta memnuniyeti anketi hazırlarken dikkate alınması gereken birçok faktör vardır.  Amaç, sadece genel memnuniyeti ölçmek değil, hizmetin hangi noktalarında iyileştirme yapılabileceğini tespit etmektir.  İşte adım adım bir kılavuz:
#
# **1. Amaç ve Hedef Kitle Tanımı:**
#
# * **Anketin amacı nedir?**  Genel memnuniyeti mi ölçmek istiyorsunuz, yoksa belirli bir departmanın (örneğin, acil servis, yoğun bakım) performansını mı değerlendirmek istiyorsunuz?
# * **Hedef kitleniz kim?**  Tüm hastaları mı, belirli bir yaş grubunu mu, veya belirli bir tedavi gören hastaları mı hedefliyorsunuz?  Anket dili ve soruları hedef kitleye uygun olmalıdır.
#
# **2. Soru Tipleri ve Formülasyonu:**
#
# Anket, hem nicel hem de nitel veriler toplamalı.  Bunun için farklı soru tiplerini kullanın:
#
# ...

# %%
#2. Stok Yönetimi (Kötü Prompt)

chat_session = model.start_chat(
  history = []
)

prompt = "Stok yönetimi hakkında bilgi ver."

response = chat_session.send_message(prompt)

print("Q: " + prompt + "\n\nA: " + response.text)
# Out:
# Q: Stok yönetimi hakkında bilgi ver.
#
# A: Stok yönetimi, bir işletmenin ürünlerini veya hammaddelerini etkili ve verimli bir şekilde yönetme sürecidir.  Amaç, müşteri talebini karşılamak için yeterli stok bulundururken, aynı zamanda depolama maliyetlerini, bozulma riskini ve fazla stok tutma maliyetini en aza indirmektir.  İyi bir stok yönetimi sistemi, işletmenin karlılığını ve rekabet gücünü artırmaya yardımcı olur.
#
# Stok yönetiminin temel unsurları şunlardır:
#
# **1. Stok Planlama:**
#
# * **Tahmin:** Gelecekteki talebi öngörmek için geçmiş verileri, pazar trendlerini ve diğer ilgili faktörleri analiz etmek.  Bu, doğru miktarda stok siparişi verilmesini sağlar.
# * **Talep tahmini:** Müşteri talebinin ne kadar olacağını tahmin etmek. Bu, çeşitli yöntemlerle (örneğin, basit ortalama, üstel düzleştirme, zaman serisi analizi) yapılabilir.
# ...

# %%
#2. Stok Yönetimi (İyi Prompt)

chat_session = model.start_chat(
  history = []
)

prompt = "Hastane malzemelerinin etkin stok yönetimi için hangi yazılımlar veya yöntemler kullanılabilir?"

response = chat_session.send_message(prompt)

print("Q: " + prompt + "\n\nA: " + response.text)
# Out:
# Q: Hastane malzemelerinin etkin stok yönetimi için hangi yazılımlar veya yöntemler kullanılabilir?
#
# A: Hastane malzemelerinin etkin stok yönetimi için çeşitli yazılımlar ve yöntemler kullanılabilir. Bunlar, hastanenin büyüklüğüne, karmaşıklığuna ve bütçesine bağlı olarak değişir.  İşte bazı seçenekler:
#
# **Yazılımlar:**
#
# * **Hastane Bilgi Sistemleri (HIS):** Birçok modern HIS, stok yönetimi modülleri içerir. Bu modüller, malzemelerin takip edilmesi, sipariş verilmesi, depo yönetimi ve stok seviyelerinin izlenmesi gibi işlevleri yerine getirir.  Genellikle entegrasyon sağladıkları için diğer sistemlerle (örneğin, malzeme yönetim sistemleri) çalışabilirler.
#
# * **Malzeme Yönetim Sistemleri (MMS):** Özel olarak hastane malzemelerinin yönetimi için tasarlanmıştır. HIS'lerden daha kapsamlı stok yönetimi özellikleri sunarlar.  Örneğin, otomatik sipariş verme, tahmine dayalı analitik, parti takip, son kullanma tarihi izleme gibi özellikler sunabilirler.
#
# ...

# %%
#3. Hasta Onam Süreci (Kötü Prompt)

chat_session = model.start_chat(
  history = []
)

prompt = "Onam formlarını nasıl yönetirim?"

response = chat_session.send_message(prompt)

print("Q: " + prompt + "\n\nA: " + response.text)
# Out:
# Q: Onam formlarını nasıl yönetirim?
#
# A: Onam formlarını etkili bir şekilde yönetmek için aşağıdaki adımları izleyebilirsiniz:
#
# **1. Form Tasarımı ve İçerik:**
#
# * **Net ve anlaşılır dil:** Onam formunuz, karmaşık yasal terimler yerine sade ve anlaşılır bir dil kullanmalıdır.  Okunabilirliği artırmak için madde işaretleri, paragraflar ve başlıklar kullanın.
# * **Spesifiklik:**  Hangi verileri topladığınızı, neden topladığınızı ve nasıl kullanacağınızı açıkça belirtin.  Genel ifadelerden kaçının.
# * **Seçenekler:** Onamın açıkça gönüllü olduğunu vurgulayın. Kişiler onamadıkları takdirde ne olacağını belirtin (örneğin, belirli bir hizmeti kullanamama).  İzin verilen seçenekleri net bir şekilde belirleyin (örneğin, sadece e-posta pazarlaması için onam, tüm iletişimler için onam, vb.).
# * **Veri Saklama Süresi:** Verileri ne kadar süre saklayacağınızı ve silme politikasını açıkça belirtin.
# ...

# %%
#3. Hasta Onam Süreci (İyi Prompt)

chat_session = model.start_chat(
  history = []
)

prompt = "Dijital hasta onam formlarını yasal gerekliliklere uygun şekilde yönetmek için hangi adımlar atılmalıdır?"

response = chat_session.send_message(prompt)

print("Q: " + prompt + "\n\nA: " + response.text)
# Out:
# Q: Dijital hasta onam formlarını yasal gerekliliklere uygun şekilde yönetmek için hangi adımlar atılmalıdır?
#
# A: Dijital hasta onam formlarını yasal gerekliliklere uygun şekilde yönetmek için dikkat edilmesi gereken birçok adım vardır. Bu adımlar, yasalara uygunluk, güvenlik ve erişilebilirliği kapsar. İşte ayrıntılı bir liste:
#
# **I. Yasal Uygunluk:**
#
# * **Uygun Mevzuata Uygunluk:**  İlgili tüm ulusal ve yerel yasaları, tıp etiği kurallarını ve veri koruma düzenlemelerini (örneğin, GDPR, HIPAA, KVKK) dikkatlice inceleyin ve dijital onam sürecinizin bu düzenlemelere tamamen uyduğundan emin olun.  Her ülkenin ve bölgenin farklı yasaları olduğundan, bu aşama oldukça önemlidir.
# * **Bilgilendirilmiş Onam İlkeleri:** Hasta, prosedür, tedavi veya araştırma hakkında tam ve anlaşılır bir şekilde bilgilendirilmelidir. Bu bilgi, prosedürün amacı, riskleri, faydaları, alternatifleri ve hasta haklarını içermelidir. Dil, okuma seviyesi ve kültürel arka plana uygun olmalıdır.
# ...
